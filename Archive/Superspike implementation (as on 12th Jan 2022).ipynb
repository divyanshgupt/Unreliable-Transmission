# %% [markdown]
# Link to paper: [Zenke, Ganguli - 2018](https://direct.mit.edu/neco/article/30/6/1514-1541/8378)
#
# Zenke's [Tutorial](https://github.com/fzenke/spytorch) on Surrogate Gradient Descent using PyTorch.
#
# To Implement:
# 1. LIF Neurons (maybe a class of such neurons)
# 2. Fast Sigmoid Function
#
# Question:
# 1. How to implement spiking neural network in pytorch?
#   * use RNNs as Zenke suggests in his tutorial?

# %%
#@title Dependencies
import numpy as np
from matplotlib import pyplot as plt


# import seaborn as sns
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
#     626         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-4996ee3d8d09> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/gdrive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     111       timeout_ms=timeout_ms,
#     112       use_metadata_server=use_metadata_server,
# --> 113       ephemeral=ephemeral)
#     114
#     115
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, use_metadata_server, ephemeral)
#     290       with _output.use_tags('dfs-auth-dance'):
#     291         with open(fifo, 'w') as fifo_file:
# --> 292           fifo_file.write(get_code(auth_prompt) + '\n')
#     293       wrote_to_fifo = True
#     294     elif case == 5:
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
images_dir = '/content/gdrive/MyDrive/Course Stuff/Sem-5/Unreliability of Synaptic Transmission/SuperSpike Implementation'

# %%
dtype = torch.float
device = torch.device("cpu")
cpu = torch.device("cpu")
# Uncomment the line below to run on GPU
#device = torch.device("cuda:0") 
gpu = torch.device("cuda:0")

# %% [markdown]
# ### Spiking Neuron Model Setup (Zenke)

# %% [markdown]
# Since we are technically stimulating an RNN, the neurons have to be simulated for a certain number of timesteps

# %% [markdown]
# Initializing weights from a normal distribution, the variance is scaled with the inverse square root of the number of input connections.
#
# Dale's Law is ignored here.

# %%
#@title The Spiking Non-linearity
def spike_fn(x):
  out = torch.zeros_like(x)
  out[x > 0] = 1.0
  return out

# %% [markdown]
# Initialize the synaptic currents and the membrane potentials at zero. Then implement a loop that stimulates the neuron models over time, and record the membrane potential and output spikes of all trials and all neurons.

# %%
# tensors initialized with zeros for synaptic current and membrane potential
syn = torch.zeros((batch_size, nb_hidden), device=device, dtype=dtype)
mem = torch.zeros((batch_size, nb_hidden), device=device, dtype=dtype)

# two lists to record the membrane potentials and output spikes
mem_rec = []
spk_rec = []

# The simulation loop
for t in range(nb_steps):
  m_thr = mem - 1.0
  out = spike_fn(m_thr)
  rst = out.detach() # we do not want to backprop through the reset

  new_syn = alpha*syn + h1[:, t]
  new_mem = (beta*mem + syn)(1 - rst)

  mem_rec.append(mem)
  spk_rec.append(out)

  mem = new_mem
  syn = new_syn

mem_rec = torch.stack(mem_rec, dim=1)
spk_rec = torch.stack(spk_rec, dim=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-a0e09aa0e370> in <module>()
#       1 # tensors initialized with zeros for synaptic current and membrane potential
# ----> 2 syn = torch.zeros((batch_size, nb_hidden), device=device, dtype=dtype)
#       3 mem = torch.zeros((batch_size, nb_hidden), device=device, dtype=dtype)
#       4
#       5 # two lists to record the membrane potentials and output spikes
#
# NameError: name 'nb_hidden' is not defined

# %%
def run_snn(inputs):

  h1 = torch.einsum('abc,cd->abd', (inputs,w1))
  syn = torch.zeros((batch_size, nb_hidden), device=device, dtype=dtype)
  mem = torch.zeros((batch_size, nb_hidden), device=device, dtype=dtype)
  # lists to record the membrane potentials and the synaptic currents:
  mem_rec = []
  spk_rec = []
  # loop to simulate time
  for t in range(nb_steps):
    mthr = mem - 1.0
    out = spike_fn(mthr)
    rst = out.detach()  # do not want to backpropagate through reset

    new_syn = alpha*syn + h1[:, t]
    new_mem = (beta*mem + syn)(1 - rst)

    mem_rec.append(mem)
    spk_rec.append(out)

    mem = new_mem
    syn = new_syn
  
  # create tensors to stack the elements in the recording lists
  mem_rec = torch.stack(mem_rec, dim=1)
  spk_rec = torch.stack(spk_rec, dim=1)

  # readout layer
  h2 = torch.einsum('abc,cd->abd', (spk_rec, w2))
  flt = torch.zeros((batch_size, nb_outputs), device=device, dtype=dtype)
  out = torch.zeros((batch_size, nb_outputs), device=device, dtype=dtype)
  out_rec = [out]
  for t in range(nb_steps):
    new_flt = alpha*flt + h2[:, t]
    new_out = beta*out + flt

    flt = new_flt
    out = new_out

    out_rec.append(out)

  out_rec = torch.stack(out_rec, dim=1)
  other_recs = [mem_rec, spk_rec]
  return out_rec, other_recs

# %% [markdown]
# ## SuperSpike Implementation

# %%
#@title Surrogate Gradient

class SurrGradSpike(torch.autograd.Function):

  scale = 100.0 # controls the steepness of the gradient

  @staticmethod
  def forward(ctx, input):
    '''
    computes a step-function on the input. ctx is a context variable
    that stores information needed later for backpropagation
    '''
    ctx.save_for_backward(input)
    out = torch.zeros_like(input)
    out[input > 0] = 1
    return out

  @staticmethod
  def backward(ctx, grad_output):
    '''
    In the backward method, we recieve a tensor we need to compute 
    the surrogradient of the loss with respect to the input. 
    Here we use the negative half of the fast sigmoid as in 
    Zenke & Ganguli 2018.
    
    '''
    input, _ = ctx.saved_tensors
    grad_input = grad_output.clone()
    grad = grad_input/(SurrGradSpike.scale*torch.abs(input)+1.0)**2
    return grad

# overwrite the spike function with the surrograte gradient function
# using the apply method
spike_fn = SurrGradSpike.apply

# %% [markdown]
# #### Loss Function
#
# The van rossum distance is evaluated as:
# $$ L = (\alpha*S_i - \alpha*\hat{S_i})^2 $$
#
# where $ \alpha $ is a double exponential filter.

# %% [markdown]
# ### Hebbian Coincidence Detection & Synaptic Eligibility Trace
#
# $$ \frac{dw_{ij}}{dt} = r\int_{-\infty}^t ds\ e_i(s)\ \alpha * [\sigma'(U_i(s))(\epsilon*S_j(s))]  $$
#
# The evalutation of this equation requires:
# 1. evaluation of presynaptic traces
# 2. evaluation of hebbian coincidence and computation of the synaptic eligibility traces
# 3. compuatation and propagation of error signals
# 4. integration of this equation and weight update
#
#
#
# Here $ \lambda_{ij} = \sigma'(U_i(s))(\epsilon*S_j(s)) $ is the eligibility trace.
#
# Fast sigmoid: $$   \sigma(x) = \frac{x}{1 + |x|} $$
#
# So, $ \sigma'(U_i) = \frac{1}{(1 + |h_i|)^2} $
#
# where $ h_i = \beta(U_i - \nu) $

# %%
def presynaptic_trace(value_exp1, value_exp2, spike, args):
  """
  Input:
    value_exp1 - 1-D array containing values of the single
                 exponential trace at the previous timestep shape: (n, 1)
    value_exp2 - 1-D array containing values of the second 
                 exponential trace at the previous timestep, shape: (n,1)
    spike - 1-D array containing 0s or 1s for n presynaptic neurons
    args['t_rise'] - 
    args['t_decay'] -
  Returns:
    the value of the presynaptic trace at the current timestep
  """
  dt = args['timestep_size']
  t_rise = args['t_rise']
  t_decay = args['t_decay']

  #print("Presynaptic Traces value_exp1, shape", value_exp1.shape)
  #print("Presynaptic Traces value_exp2, shape", value_exp2.shape)
  
  z = value_exp1 + (-value_exp1/t_rise + spike)*dt
  z_hat = value_exp2 + (-value_exp2 + value_exp1)*dt/t_decay
  
  return z, z_hat

# %%
def presynaptic_trace_2(input_trains, args):
  """
  Evaluates the presynaptic trace (double exponential kernel)
  given the whole input trains
  Inputs:
    input_trains
    args:['timestep_size', 't_rise', 't_decay', 'nb_steps']
  Returns:
    Presynaptic Trace 
  """
  dt = args['timestep_size']
  t_rise = args['t_rise']
  t_decay = args['t_decay']
  nb_timesteps = args['nb_steps']
  nb_trains = len(input_trains)

  trace_1 = torch.zeros((nb_trains, nb_timesteps), device=device, dtype=dtype)
  trace_2 = torch.zeros((nb_trains, nb_timesteps), device=device, dtype=dtype)

  for t in range(nb_timesteps - 1):
    trace_1[:, t+1] = trace_1[:, t] + (-trace_1[:, t]/t_rise + input_trains[:, t])*dt
    trace_2[:, t+1] = trace_2[:, t] + (-trace_2[:, t] + trace_1[:, t])*dt/t_decay

  return trace_2

# %%
def eligibility_trace(mem, spike_train, args):
  """
  input:
    mem: membrane potential of i-th neuron for all 
         relevant timesteps, 1-D array shape: (timesteps)
    spike_train: j-th neuron, 1-D array, shape: (timesteps)
    thres: firing threshold
  Returns:
    eligibility trace
  """
  thres = args['thres']
  t_rise = args['t_rise']
  t_decay = args['t_decay']
  
  beta = 1 # mV^-1
  h_i = beta*(mem - thres)

  post = 1 / (1 + torch.abs(h_i))**2 
  pre_synaptic_trace = doubleExponential(spike_train, dt, t_rise, t_decay, time)

  hebbian = post * pre_synaptic_trace #hebbian coincidence term

  #synaptic eligibility trace
  eligibility_trace = doubleExponential(hebbian, dt, t_rise, t_decay, time)

  return elibility_trace

# %% [markdown]
# ### Error Signal

# %%
#@title Output Error Signal

def error_signal(spike_train, desired_spike_train):
  """
  Returns the error signal (time series)
  """
  # output spike train
  filter_1 = doubleExponential(spike_train, dt, t_rise,
                               t_decay, time)
  # desired spike train
  filter_2 = doubleExponential(desired_spike_train, dt, t_rise,
                               t_decay, time)
  
  error = filter_2 - filter_1
  return error

# %%
def error_signal2(value_exp1, value_exp2, output, target, args):
  """

  """

  t_rise = args['t_rise_alpha']
  t_decay = args['t_decay_alpha']
  dt = args['timestep_size']

  difference = target - output

  z = value_exp1 + (-value_exp1/t_rise + difference)*dt
  z_hat = value_exp2 + (-value_exp2 + value_exp1)*dt/t_decay


  return z, z_hat

# %%
#@title Error Signal 3
def error_signal3(output, target, args):
  """
  Evaluates the error signal by running the double exponential 
  kernel on the difference of the output and the target spike trains.
  Inputs:
    output - spike_train, shape: (nb_timesteps,)
    target - spike_train, shape: (nb_timesteps,)
    args:['timestep_size', 't_rise_alpha', 't_decay_alpha', 'nb_steps']
  Returns
    Error Signal Trace of shape: (nb_timesteps,)
  """
  t_rise = args['t_rise_alpha']
  t_decay = args['t_decay_alpha']
  dt = args['timestep_size']
  nb_timesteps = args['nb_steps']

  trace_1 = torch.zeros(nb_timesteps, device=device, dtype=dtype)
  trace_2 = torch.zeros(nb_timesteps, device=device, dtype=dtype)

 # print("Target Shape", target.shape)
 # print("Output Shape", output.shape)
  difference = target - output
 # print("Difference Shape", difference.shape)

  for t in range(nb_timesteps - 1):
    trace_1[t + 1] = trace_1[t] + (-trace_1[t]/t_rise + difference[t])*dt
    trace_2[t + 1] = trace_2[t] + (-trace_2[t] + trace_1[t])*dt/t_decay

  return trace_2

# %%
#@title Feedback Signal

def feedback_signal():
  """
  
  Returns:

  """


  return feedback

# %% [markdown]
# ### Per Parameter Learning Rate
#
# Zenke & Ganguli (2018) used a per parameter learning rate. **bold text**

# %%
def learning_rate():
  """

  """

# %% [markdown]
# ### Regularization Term
#
# Heterosynaptic regularization term to the learning rule of the hidden layers to avoid pathologically high firing rates.

# %%
def regularization_term():
# Out:
#   File "<ipython-input-11-ff8177726daa>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ### Poisson Spike Trains
#
# Based on the method suggested by David Heeger [here](https://www.cns.nyu.edu/~david/handouts/poisson.pdf)

# %%
def Poisson_trains(n, lam, timesteps, dt):
  """

  inputs:
    n - number of poisson spike trains 
    lam - 1-D array containing mean value of poisson trains
  Returns

  """
  trains = torch.zeros((n, timesteps), device=device, dtype=dtype)
  unif = torch.rand((n, timesteps), device=device, dtype=dtype)

#  counter = 0
  for i in range(n):
    trains[unif <= lam[i]*dt] = 1
#    counter += len(unif <= lam[i]*dt)
#  print("Total No. of Spikes", counter)

  return trains

# %%
trains = Poisson_trains(1, 1000*np.ones(10), 1000, 1e-4)

#print(trains)

# %%
#@title Step Function for Spikes
def spike_fn(x, thres):
  """
  Implements a heaviside function centred at the firing threshold
  """
  x = x - thres
  out = torch.zeros_like(x, device=device, dtype=dtype)
  out[x > 0] = 1
  return out

# %%
#@title Old van Rossum Loss
def van_rossum_loss(output, target, args):

  z = 0
  z_hat = 0
  t_rise = args['t_rise_alpha']
  t_decay = args['t_decay_alpha']
  dt = args['timestep_size']

  loss = 0

  #output = output.flatten(start_dim=1)

  #print("Output Spike Train Shape:", output.shape)
  #print("Target Spike Train Shape:", target.shape)

 # print((target - output).shape)

  for i in range(len(output)):

    difference = target[i] - output[i]
    #print(difference.shape)
    z = z + (-z/t_rise + difference)*dt
    z_hat = z_hat + (-z_hat + z)*dt/t_decay
    
    loss += dt*(z_hat**2) 

  return (1/2)*loss

# %%
#@title New van Rossum Loss
def van_rossum_loss2(output, target, args):
  """
  Evaluates the van rossum loss over the normalized double-exponential kernel
  Inputs:
    output - spiketrain, shape: (nb_steps,)
    target - spiketrain, shape: (nb_steps,)
  Returns
    van Rossum loss (over normalized double exponential error signal)
  """

  t_rise = args['t_rise_alpha']
  t_decay = args['t_decay_alpha']
  dt = args['timestep_size']
  nb_steps = args['nb_steps']

  difference = target - output
 # print(difference.shape)

  trace_1 = torch.zeros(nb_steps, device=device, dtype=dtype)
  trace_2 = torch.zeros(nb_steps, device=device, dtype=dtype)

  for t in range(nb_steps - 1):
    trace_1[t+1] = trace_1[t] + (-trace_1[t]/t_rise + difference[t])*dt
    trace_2[t+1] = trace_2[t] + (-trace_2[t]/t_decay + trace_1[t])*dt/t_decay

  # normalizing the double exponential convolution
  normalization_factor = torch.max(trace_2)
 # print("Normalization factor:", normalization_factor)
  trace_2 = trace_2/normalization_factor
 # print(torch.max(trace_2))
  loss = torch.sum(trace_2**2)*dt
  
  return loss

# %%
def eligibility_trace2(value_exp1, value_exp2, hebbian, args):
  """
  i: no. of presynaptic neurons
  j: no. of postsynaptic neurons
  Input:
    value_exp1 - 2-D array containing values of the single exponential
                 trace at the previous timestep. Shape: (i, j)
    value_exp2 - 2-D array containing values of the second exponential
                 trace at the previous timestep Shape: (i, j)
    hebbian - 2-D array
    args['t_rise_alpha']
    args['t_decay_alpha']
  Returns:

  """
  dt = args['timestep_size']
  t_rise = args['t_rise_alpha']
  t_decay = args['t_decay_alpha']

#  print("last eligibility Value_exp1 shape:", value_exp1.shape)
#  print("last eligibility Value_exp2 shape:", value_exp2.shape)
#  print("hebbian shape", hebbian.shape)

  z = value_exp1 + (-value_exp1/t_rise + hebbian)*dt
  z_hat = value_exp2 + (-value_exp2 + value_exp1)*dt/t_decay

  return z, z_hat

# %%
def eligibility_trace3(hebbian, args):
  """
  Evaluate the hebbian-coincidence based eligibility trace over all timesteps
  for all the given synaptic connections in the hebbian matrix using the 
  double exponential kernel.
  Inputs:
    hebbian - 2-D matrix of shape: (nb_inputs, nb_outputs)
    args: ['timestep_size', 't_rise_alpha', 't_decay_alpha', 'nb_steps']
  Returns:
    Eligibilty trace matrix of shape: (nb_inputs, nb_outputs, nb_timesteps)
  """
  dt = args['timestep_size']
  t_rise = args['t_rise_alpha']
  t_decay = args['t_decay_alpha']
  nb_timesteps = args['nb_steps']
  nb_inputs = hebbian.shape[0]
  nb_outputs = hebbian.shape[1]

  trace_1 = torch.zeros((nb_inputs, nb_outputs, nb_timesteps), device=device,
                       dtype=dtype)
  trace_2 = torch.zeros((nb_inputs, nb_outputs, nb_timesteps), device=device,
                        dtype=dtype)

  for t in range(nb_timesteps-1):
    trace_1[:, :, t+1] = trace_1[:, :, t] + (-trace_1[:, :, t]/t_rise + hebbian[:, :, t])*dt
    trace_2[:, :, t+1] = trace_2[:, :, t] + (-trace_2[:, :, t] + trace_1[:, :, t])*dt/t_decay

  return trace_2

# %% [markdown]
# ### Single Neuron Model

# %% [markdown]
# Property | Value|
# -----| -----|
# threshold | -50 mV
# U_rest | -60 mV
# tau_mem| 10 ms
# tau_syn| 5 ms
# tau_ref| 5 ms

# %%
# LIF Neuron Model Parameters
args = {'thres': -50,
        'u_rest': -60,
        'tau_mem': 1e-2,
        'tau_syn': 5e-3,
        'tau_ref': 5e-3,
        't_rise': 5e-3, # the pre-synaptic double exponential kernel rise time
        't_decay': 1e-2, # the pre-synaptic double exponential kernel decay time
        'timestep_size': 1e-4, # 0.1 msec timesteps
        't_rise_alpha': 5e-3,
        't_decay_alpha': 1e-2,
        'nb_steps': 5000,
        'tau_rms': 5e-3} # this is a guess and might need changing

# %%
nb_inputs = 100 # 100 spike trains as inputs that repeat every 500 ms
nb_outputs = 1 

batch_size = 256

nb_steps = args['nb_steps']
timestep_size = args['timestep_size']

# %%
tau_syn = args['tau_syn']
tau_mem = args['tau_mem']

alpha = float(np.exp(-timestep_size/tau_syn))
beta = float(np.exp(-timestep_size/tau_mem))

# %%
#@title Input Spike Trains

spk_freq = 10 # not sure about this, but assuming it since the paper
# uses 10 Hz frequency as the target output frequency (actually 
# 5 equidistant spikes over 500 ms)

input_trains = Poisson_trains(100, spk_freq*np.ones(100),
                              nb_steps, timestep_size)

# %%
#@title Target Spike Train
## 5 equidistant spikes spread over 0.5 secs
target = torch.zeros(nb_steps, device=device, dtype=dtype)
target[:: nb_steps//5] = 1

# %%
#@title Weight Initialization

def initialize_weights(nb_inputs, nb_outputs, scale=70):

  weight_scale = scale*(1 - 0) # copied from spytorch

  weights = torch.empty((nb_inputs, nb_outputs), device=device, dtype=dtype)
  weights = torch.nn.init.normal_(weights, mean=0.5, std=weight_scale/np.sqrt(nb_inputs))
  print("Weight initialization done")
  return weights

# %%
weights = initialize_weights(nb_inputs, nb_outputs)
# Out:
# Weight initialization done

# %%
def plot_weight_distribution(weights):
  weights = torch.flatten(weights).to('cpu')
  plt.hist(weights, bins='fd')
  plt.title("Weights Distribution")
  plt.show()

plot_weight_distribution(weights)

# %%
a = [1, 2, 3]
print(a[-2:])
print(a[-0:])
# Out:
# [2, 3]
# [1, 2, 3]

# %%
#@title Purely Online Implementation
thres = args['thres']
u_rest = args['u_rest']

mem = u_rest * torch.ones(nb_outputs, device=device, dtype=dtype)
syn = torch.zeros(nb_outputs, device=device, dtype=dtype)

epochs = 1


loss_rec = []
for i in tqdm(range(epochs)):

  m = 0
  mem_rec = []
  spk_rec = []

  eligibility_trace_record = torch.zeros((nb_inputs, nb_steps), device=device, dtype=dtype)
 # pre_trace_rec = torch.zeros((nb_inputs, nb_inputs, nb_steps), device=device, dtype=dtype)
  

  eligibility_rec = []
  pre_trace_rec = []
  error_rec = []

  last_presynaptic_traces = [torch.zeros(nb_inputs, device=device, dtype=dtype),
                             torch.zeros(nb_inputs, device=device, dtype=dtype)]
  last_eligibility_traces = [torch.zeros(nb_inputs, device=device, dtype=dtype),
                             torch.zeros(nb_inputs, device=device, dtype=dtype)] # not sure about the shape here, might have to recheck

  last_error_values = [torch.zeros(nb_inputs, device=device, dtype=dtype),
                       torch.zeros(nb_inputs, device=device, dtype=dtype)]

  reset = 0
  for t in range(nb_steps):

    out = spike_fn(mem, thres)

    spk_rec.append(out)
    mem_rec.append(mem)

    # refractory period = 5 ms = 50 timesteps of 0.1 ms each
    if t < 50:
      if 1 in spk_rec:
        reset = 1
      #  print("Reseting membrane potential to resting value")
    elif 1 in spk_rec[-50:]:
      reset = 1
    else:
      reset = 0

 #   weights = torch.flatten(weights)

    weighted_inp = torch.sum(input_trains[:, t] * weights.T)
    new_syn = alpha*syn + weighted_inp
    new_mem = (beta*mem + syn*(1 - beta) + u_rest*(1 - beta))*(1 - reset) + (reset * u_rest)

    mem = new_mem
    syn = new_syn
    
    # compute presynaptic traces
    presynaptic_traces = presynaptic_trace(last_presynaptic_traces[0],
                                           last_presynaptic_traces[1],
                                           input_trains[:, t], args)    
    last_presynaptic_traces = presynaptic_traces
    pre_trace_rec.append(presynaptic_traces[1])

    # evaluate hebbian coincidence
    h = mem - thres
    post = 1 / (1 + torch.abs(h))**2
    hebbian = post * presynaptic_traces[1]

    # eligibility trace
    synaptic_eligibility = eligibility_trace2(last_eligibility_traces[0],
                                              last_eligibility_traces[1],
                                              hebbian, args)
    last_eligibility_traces = synaptic_eligibility
    eligibility_rec.append(synaptic_eligibility[1])
  
    # error signal
    error = error_signal2(last_error_values[0], last_error_values[1],
                          out, target[t], args)
    last_error_values = error
    error_rec.append(error[1])

    # for minibatching weight updates in time
    m += error[1] * synaptic_eligibility[1]
 # weights += m

  # loss evaluation
  spk_rec = torch.stack(spk_rec, dim=0)
  loss = van_rossum_loss(spk_rec, target, args)
  print("Loss =", loss)
  loss_rec.append(loss)

  # stacking and flattening recordings
  spk_rec = torch.flatten(spk_rec)
  print("Spike train:", spk_rec)
  error_rec = torch.stack(error_rec, dim=0)
  eligibility_rec = torch.stack(eligibility_rec, dim=1)
  pre_trace_rec = torch.stack(pre_trace_rec, dim = 1)
 
  j = 5
  #plot_traces(eligibility_rec, pre_trace_rec, input_trains, j)
  e1 = eligibility_rec.to(cpu)
  p1 = pre_trace_rec.to(cpu)
  inp = input_trains.to(cpu)
  plot_traces(e1, p1, inp, j)

 # mem_cpu = mem_rec.to(cpu)
  spk_cpu = spk_rec.to(cpu)
  error_rec_cpu = error_rec.to(cpu)
  target_cpu = target.to(cpu)
  plot_neuron_dynamics(mem_rec, spk_cpu, error_rec_cpu, target_cpu)

#print(loss_rec)
#plt.plot(loss_rec)
# Out:
#   0%|          | 0/1 [00:03<?, ?it/s]
# Loss = tensor([2.5892e-11])
# Spike train: tensor([0., 0., 0.,  ..., 0., 0., 0.])
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-d41dda448a57> in <module>()
#     106   p1 = pre_trace_rec.to(cpu)
#     107   inp = input_trains.to(cpu)
# --> 108   plot_traces(e1, p1, inp, j)
#     109
#     110  # mem_cpu = mem_rec.to(cpu)
#
# NameError: name 'plot_traces' is not defined

# %%
#plot_traces(eligibility_rec, pre_trace_rec, input_trains, j)
plot_traces(eligibility_rec, pre_trace_rec, input_trains, 1)
plot_traces(eligibility_rec, pre_trace_rec, input_trains, 2)
plot_traces(eligibility_rec, pre_trace_rec, input_trains, 3)

# %% [markdown]
# #### Raster Plot

# %%
def plot_single_train(spike_train, nb_steps, timestep_size, idx=0):

  positions = np.arange(0, nb_steps)
  spike_positions = positions[spike_train == 1]
 # print(spike_positions)
  plt.eventplot(spike_positions, lineoffsets=idx)
  plt.xlim(0, nb_steps)
  #plt.show()

def plot_trains(spike_trains, title='Spike Trains'):
  plt.figure(dpi = 100)
  for i in range(len(spike_trains)):
    plot_single_train(spike_trains[i], nb_steps, timestep_size, idx=i)
  plt.title(title)
  plt.xlabel('Timestep')
  plt.ylabel('Spike Train No.')
  plt.show()


def plot_traces(eligiblity_rec, pre_synaptic_rec, input_trains, idx):
    
  j = idx

  fig, axs = plt.subplots(3, sharex=True, figsize=(15,10), dpi=120)

  axs[0].plot(eligibility_rec[j])
  axs[0].set_title("Eligibility Trace No." + str(j))
 
  positions = np.arange(0, nb_steps)
  spike_positions = positions[input_trains[j] == 1]
  axs[1].eventplot(spike_positions)
  axs[1].set_title("Corresponding Input Train No." + str(j))
  axs[1].set_xlim([0, nb_steps])

  axs[2].plot(pre_trace_rec[j])
  axs[2].set_title("Presynaptic Trace No." + str(j))

  for ax in axs.flat:
    ax.set(xlabel = "Timestep")
    # Hide x labels and tick labels for top plots and y ticks for right plots:
    ax.label_outer()

 # fig.show()

def plot_neuron_dynamics(mem_rec, spk_rec, error_rec, target):

  fig, axs = plt.subplots(4, sharex=True, figsize=(15, 10), dpi=120)

  ## Plot the target spike train
  positions = np.arange(0, nb_steps)
  spike_positions = positions[target == 1]
  axs[0].eventplot(spike_positions)
  axs[0].set_title("Target Spike Train")
  axs[0].set_xlim([0, nb_steps])

  ## Plot error signal
  axs[1].plot(error_rec)
  axs[1].set_title("Error Signal")

  ## Plot output spike train
  positions = np.arange(0, nb_steps)
  spike_positions = positions[spk_rec == 1]
  axs[2].eventplot(spike_positions)
  axs[2].set_title("Output Spike Train")
  axs[2].set_xlim([0, nb_steps])

  ## Plot membrane potential
  axs[3].plot(mem_rec)
  axs[3].set_title("Membrane Potential")
  axs[3].set_ylabel("Potential (in mV)")

  for ax in axs.flat:
    ax.set(xlabel = "Timestep")
    # Hide x labels and tick labels for top plots and y ticks for right plots:
    ax.label_outer()

 # fig.show()

# %%
plot_single_train(target, nb_steps, timestep_size)
plt.show()

plot_trains(input_trains, title = "Input Trains")

# %%
def run_single_neuron(input_trains, weights, target, args):
  """
  Run a single LIF neuron as specificed by Zenke Ganguli for one epoch
  Inputs:
    input_trains
    weights
    target - desired spike train
    args['thres']
    args['u_rest']
  Returns:
    mem_rec, spk_rec, eligibility_rec, presynaptic_traces, error_signal

  """
  thres = args['thres']
  u_rest = args['u_rest']
  nb_steps = args['nb_steps']

  # initialize membrane and synaptic current 
  mem = u_rest * torch.ones(nb_outputs, device=device, dtype=dtype)
  syn = torch.zeros(nb_outputs, device=device, dtype=dtype)

  # lists to store traces and neuron variables
  mem_rec = []
  spk_rec = []
  eligibility_rec = []
  pre_trace_rec = []
  error_rec = []

  reset = 0

  for t in range(nb_steps):

    out = spike_fn(mem, thres)

    spk_rec.append(out)
    mem_rec.append(mem)

    # refractory period = 5 ms = 50 timesteps of 0.1 ms each
    if t < 50:
      if 1 in spk_rec:
        reset = 1
     #   print("Reseting membrane potential to resting value")
    elif 1 in spk_rec[-50:]:
      reset = 1
    else:
      reset = 0

    # LIF membrane potential update
    weighted_inp = torch.sum(input_trains[:, t] * weights.T)
    new_syn = alpha*syn + weighted_inp
    new_mem = (beta*mem + syn*(1 - beta) + u_rest*(1 - beta))*(1 - reset) + (reset * u_rest)

    mem = new_mem
    syn = new_syn
  # end of simulation loop
  
  mem_rec = torch.stack(mem_rec, dim=0)
  spk_rec = torch.stack(spk_rec, dim=0)
  spk_rec = torch.flatten(spk_rec) # stack as a 1-D array for easy difference with target train for error signal evaluation
  # compute presynaptic traces of shape: (nb_inputs, timesteps) 
  presynaptic_traces = presynaptic_trace_2(input_trains, args) 

  # evaluate hebbian coincidence
  h = mem_rec.T - thres  # shape: (nb_outputs, timesteps)
  post = 1 / (1 + torch.abs(h))**2 # shape: (nb_outputs, timesteps) 
  A = torch.unsqueeze(presynaptic_traces, 1)
  B = torch.unsqueeze(post, 0)
  hebbian = A * B # AB.T shape: (nb_inputs, nb_outputs, nb_timesteps)

  # eligibility trace
  eligibility = eligibility_trace3(hebbian, args)
  
  # error signal
  error = error_signal3(spk_rec, target, args)

  return mem_rec, spk_rec, error, eligibility, presynaptic_traces

# %%
#@title Running better neuron
num_epochs = 1

for i in range(epochs):
  mem_rec, spk_rec, error_rec, eligibility_rec, pre_trace_rec = run_single_neuron(input_trains, weights,
                                                                                  target, args)
  loss = van_rossum_loss(spk_rec, target, args)
  print("Loss = ", loss)
# Out:
# Loss =  tensor(3.1174e-11)

# %%
plot_neuron_dynamics(mem_rec, spk_rec, error_rec, target)

# %%
#@title Doing Weight Updates

dt = args['timestep_size']
weights = initialize_weights(nb_inputs, nb_outputs, scale=80)
print(type(weights))
plot_weight_distribution(weights)
epochs = 500
v_ij = 1e-2*torch.ones((nb_inputs, nb_outputs), device=device, dtype=dtype)
r_0 = 5e-3 # basal learning rate
loss_rec = []
iteration = 0

for i in range(epochs):
  iteration += 1
  print("\n Iteration no:", iteration)
  mem_rec, spk_rec, error_rec, eligibility_rec, pre_trace_rec = run_single_neuron(input_trains, weights,
                                                                                  target, args)
 # loss = van_rossum_loss(spk_rec, target, args)
 # print("Loss = ", loss)
  norm_loss = van_rossum_loss2(spk_rec, target, args)
  print("Normalized Loss =", norm_loss)
  loss_rec.append(norm_loss.to(cpu))
  # normalizing the eligibility trace:
 # print("Eligibilty shape:", eligibility_rec.shape)
  norm_factor, _ = torch.max(torch.abs(eligibility_rec), dim=2) # take max along time dimension for each i-jth synapse
 # print("Eligibility Norm_factor shape:", norm_factor.shape)
  norm_factor = torch.unsqueeze(norm_factor, 2)
 # print("Normalization Factor for Eligibility:",norm_factor)
 # print("Eligibility Norm_factor shape after unsequeeze:", norm_factor.shape)
  eligibility_rec = eligibility_rec / norm_factor
 # print("Normalized Eligibility rec:", eligibility_rec)
  eligibility_rec[eligibility_rec != eligibility_rec] = 0
 # print(torch.max(eligibility_rec))
 # print("eligibility_rec shape:", eligibility_rec.shape)

  # normalizing the error signal:
  norm_factor = torch.max(torch.abs(error_rec))
  error_rec = error_rec / norm_factor
#  print("max error value:", torch.max(error_rec))
#  print("Post normalization Error rec:", error_rec)
 # print("Error Signal shape:", error_rec.shape)
  # Weight update
  weight_updates = torch.sum(error_rec * eligibility_rec, dim=2)
  #print(weight_updates.shape)
#  print("Weight Updates:", weight_updates.T)

  # per-parameter learning rate
  gamma = float(np.exp(-dt/args['tau_rms']))
 # print("Gamma =", gamma)
 # g_ij2 = (error_rec * eligibility_rec)[:, :, -1]**2

  g_ij2 = torch.sum((error_rec * eligibility_rec)**2, dim=2)
  
#  print("g_ij2 =", g_ij2)
  v_ij = torch.max(gamma*v_ij, g_ij2)

  r_ij = r_0 / torch.sqrt(v_ij)
  rate_med = torch.median(r_ij)
  print("Median Learning Rate:", rate_med)
  rate_mean = torch.mean(r_ij)
  print("Avg. Learning Rate:", rate_mean)
#  print("Per-parameter learning rates:", r_ij.T)
#  print("change in weights =", (r_ij*weight_updates).T)
  weights += r_ij * weight_updates
#  plot_neuron_dynamics(mem_rec, spk_rec, error_rec, target)

#plt.savefig(f"{images_dir}/10 epoch evolution.png")
plt.plot(loss_rec)
# Out:
# Weight initialization done
# <class 'torch.Tensor'>
#  Iteration no: 1
# torch.Size([5000])
# Normalized Loss = tensor(0.0335)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0018)
#
#  Iteration no: 2
# torch.Size([5000])
# Normalized Loss = tensor(0.0331)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0017)
#
#  Iteration no: 3
# torch.Size([5000])
# Normalized Loss = tensor(0.0319)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0016)
#
#  Iteration no: 4
# torch.Size([5000])
# Normalized Loss = tensor(0.0300)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 5
# torch.Size([5000])
# Normalized Loss = tensor(0.0294)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 6
# torch.Size([5000])
# Normalized Loss = tensor(0.0258)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 7
# torch.Size([5000])
# Normalized Loss = tensor(0.0257)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 8
# torch.Size([5000])
# Normalized Loss = tensor(0.0255)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 9
# torch.Size([5000])
# Normalized Loss = tensor(0.0251)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0014)
#
#  Iteration no: 10
# torch.Size([5000])
# Normalized Loss = tensor(0.0223)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0014)
#
#  Iteration no: 11
# torch.Size([5000])
# Normalized Loss = tensor(0.0197)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0014)
#
#  Iteration no: 12
# torch.Size([5000])
# Normalized Loss = tensor(0.0197)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0014)
#
#  Iteration no: 13
# torch.Size([5000])
# Normalized Loss = tensor(0.0219)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0014)
#
#  Iteration no: 14
# torch.Size([5000])
# Normalized Loss = tensor(0.0196)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0014)
#
#  Iteration no: 15
# torch.Size([5000])
# Normalized Loss = tensor(0.0195)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 16
# torch.Size([5000])
# Normalized Loss = tensor(0.0216)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 17
# torch.Size([5000])
# Normalized Loss = tensor(0.0168)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0014)
#
#  Iteration no: 18
# torch.Size([5000])
# Normalized Loss = tensor(0.0209)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0014)
#
#  Iteration no: 19
# torch.Size([5000])
# Normalized Loss = tensor(0.0168)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0014)
#
#  Iteration no: 20
# torch.Size([5000])
# Normalized Loss = tensor(0.0186)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 21
# torch.Size([5000])
# Normalized Loss = tensor(0.0208)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 22
# torch.Size([5000])
# Normalized Loss = tensor(0.0153)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 23
# torch.Size([5000])
# Normalized Loss = tensor(0.0193)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0014)
#
#  Iteration no: 24
# torch.Size([5000])
# Normalized Loss = tensor(0.0152)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0014)
#
#  Iteration no: 25
# torch.Size([5000])
# Normalized Loss = tensor(0.0191)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0014)
#
#  Iteration no: 26
# torch.Size([5000])
# Normalized Loss = tensor(0.0149)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 27
# torch.Size([5000])
# Normalized Loss = tensor(0.0167)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 28
# torch.Size([5000])
# Normalized Loss = tensor(0.0192)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0014)
#
#  Iteration no: 29
# torch.Size([5000])
# Normalized Loss = tensor(0.0190)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 30
# torch.Size([5000])
# Normalized Loss = tensor(0.0151)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 31
# torch.Size([5000])
# Normalized Loss = tensor(0.0192)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 32
# torch.Size([5000])
# Normalized Loss = tensor(0.0150)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 33
# torch.Size([5000])
# Normalized Loss = tensor(0.0191)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 34
# torch.Size([5000])
# Normalized Loss = tensor(0.0169)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 35
# torch.Size([5000])
# Normalized Loss = tensor(0.0191)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 36
# torch.Size([5000])
# Normalized Loss = tensor(0.0152)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 37
# torch.Size([5000])
# Normalized Loss = tensor(0.0146)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 38
# torch.Size([5000])
# Normalized Loss = tensor(0.0169)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 39
# torch.Size([5000])
# Normalized Loss = tensor(0.0176)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 40
# torch.Size([5000])
# Normalized Loss = tensor(0.0216)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 41
# torch.Size([5000])
# Normalized Loss = tensor(0.0176)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 42
# torch.Size([5000])
# Normalized Loss = tensor(0.0192)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 43
# torch.Size([5000])
# Normalized Loss = tensor(0.0147)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 44
# torch.Size([5000])
# Normalized Loss = tensor(0.0174)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0015)
#
#  Iteration no: 45
# torch.Size([5000])
# Normalized Loss = tensor(0.0150)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0016)
#
#  Iteration no: 46
# torch.Size([5000])
# Normalized Loss = tensor(0.0191)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0016)
#
#  Iteration no: 47
# torch.Size([5000])
# Normalized Loss = tensor(0.0174)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0016)
#
#  Iteration no: 48
# torch.Size([5000])
# Normalized Loss = tensor(0.0189)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0016)
#
#  Iteration no: 49
# torch.Size([5000])
# Normalized Loss = tensor(0.0154)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0016)
#
#  Iteration no: 50
# torch.Size([5000])
# Normalized Loss = tensor(0.0169)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0016)
#
#  Iteration no: 51
# torch.Size([5000])
# Normalized Loss = tensor(0.0169)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0016)
#
#  Iteration no: 52
# torch.Size([5000])
# Normalized Loss = tensor(0.0172)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0016)
#
#  Iteration no: 53
# torch.Size([5000])
# Normalized Loss = tensor(0.0151)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0016)
#
#  Iteration no: 54
# torch.Size([5000])
# Normalized Loss = tensor(0.0167)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0017)
#
#  Iteration no: 55
# torch.Size([5000])
# Normalized Loss = tensor(0.0176)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0017)
#
#  Iteration no: 56
# torch.Size([5000])
# Normalized Loss = tensor(0.0214)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0016)
#
#  Iteration no: 57
# torch.Size([5000])
# Normalized Loss = tensor(0.0151)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0016)
#
#  Iteration no: 58
# torch.Size([5000])
# Normalized Loss = tensor(0.0167)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0016)
#
#  Iteration no: 59
# torch.Size([5000])
# Normalized Loss = tensor(0.0176)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0016)
#
#  Iteration no: 60
# torch.Size([5000])
# Normalized Loss = tensor(0.0173)
# Median Learning Rate: tensor(0.0005)
# Avg. Learning Rate: tensor(0.0017)
#
#  Iteration no: 61
# torch.Size([5000])
# Normalized Loss = tensor(0.0169)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0017)
#
#  Iteration no: 62
# torch.Size([5000])
# Normalized Loss = tensor(0.0154)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0017)
#
#  Iteration no: 63
# torch.Size([5000])
# Normalized Loss = tensor(0.0147)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0017)
#
#  Iteration no: 64
# torch.Size([5000])
# Normalized Loss = tensor(0.0194)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0017)
#
#  Iteration no: 65
# torch.Size([5000])
# Normalized Loss = tensor(0.0176)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0017)
#
#  Iteration no: 66
# torch.Size([5000])
# Normalized Loss = tensor(0.0171)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0017)
#
#  Iteration no: 67
# torch.Size([5000])
# Normalized Loss = tensor(0.0145)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0017)
#
#  Iteration no: 68
# torch.Size([5000])
# Normalized Loss = tensor(0.0174)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0017)
#
#  Iteration no: 69
# torch.Size([5000])
# Normalized Loss = tensor(0.0170)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0018)
#
#  Iteration no: 70
# torch.Size([5000])
# Normalized Loss = tensor(0.0198)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0018)
#
#  Iteration no: 71
# torch.Size([5000])
# Normalized Loss = tensor(0.0175)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0018)
#
#  Iteration no: 72
# torch.Size([5000])
# Normalized Loss = tensor(0.0145)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0018)
#
#  Iteration no: 73
# torch.Size([5000])
# Normalized Loss = tensor(0.0175)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0018)
#
#  Iteration no: 74
# torch.Size([5000])
# Normalized Loss = tensor(0.0170)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0018)
#
#  Iteration no: 75
# torch.Size([5000])
# Normalized Loss = tensor(0.0197)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0018)
#
#  Iteration no: 76
# torch.Size([5000])
# Normalized Loss = tensor(0.0152)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0018)
#
#  Iteration no: 77
# torch.Size([5000])
# Normalized Loss = tensor(0.0169)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0018)
#
#  Iteration no: 78
# torch.Size([5000])
# Normalized Loss = tensor(0.0176)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0018)
#
#  Iteration no: 79
# torch.Size([5000])
# Normalized Loss = tensor(0.0196)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0019)
#
#  Iteration no: 80
# torch.Size([5000])
# Normalized Loss = tensor(0.0192)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0019)
#
#  Iteration no: 81
# torch.Size([5000])
# Normalized Loss = tensor(0.0151)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0019)
#
#  Iteration no: 82
# torch.Size([5000])
# Normalized Loss = tensor(0.0190)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0019)
#
#  Iteration no: 83
# torch.Size([5000])
# Normalized Loss = tensor(0.0176)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0019)
#
#  Iteration no: 84
# torch.Size([5000])
# Normalized Loss = tensor(0.0195)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0019)
#
#  Iteration no: 85
# torch.Size([5000])
# Normalized Loss = tensor(0.0170)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0020)
#
#  Iteration no: 86
# torch.Size([5000])
# Normalized Loss = tensor(0.0169)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0020)
#
#  Iteration no: 87
# torch.Size([5000])
# Normalized Loss = tensor(0.0198)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0020)
#
#  Iteration no: 88
# torch.Size([5000])
# Normalized Loss = tensor(0.0245)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0020)
#
#  Iteration no: 89
# torch.Size([5000])
# Normalized Loss = tensor(0.0152)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0020)
#
#  Iteration no: 90
# torch.Size([5000])
# Normalized Loss = tensor(0.0168)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0020)
#
#  Iteration no: 91
# torch.Size([5000])
# Normalized Loss = tensor(0.0198)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0020)
#
#  Iteration no: 92
# torch.Size([5000])
# Normalized Loss = tensor(0.0195)
# Median Learning Rate: tensor(0.0005)
# Avg. Learning Rate: tensor(0.0020)
#
#  Iteration no: 93
# torch.Size([5000])
# Normalized Loss = tensor(0.0147)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0020)
#
#  Iteration no: 94
# torch.Size([5000])
# Normalized Loss = tensor(0.0191)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0021)
#
#  Iteration no: 95
# torch.Size([5000])
# Normalized Loss = tensor(0.0176)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0021)
#
#  Iteration no: 96
# torch.Size([5000])
# Normalized Loss = tensor(0.0195)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0021)
#
#  Iteration no: 97
# torch.Size([5000])
# Normalized Loss = tensor(0.0178)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0021)
#
#  Iteration no: 98
# torch.Size([5000])
# Normalized Loss = tensor(0.0169)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0021)
#
#  Iteration no: 99
# torch.Size([5000])
# Normalized Loss = tensor(0.0191)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0022)
#
#  Iteration no: 100
# torch.Size([5000])
# Normalized Loss = tensor(0.0151)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0022)
#
#  Iteration no: 101
# torch.Size([5000])
# Normalized Loss = tensor(0.0220)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0022)
#
#  Iteration no: 102
# torch.Size([5000])
# Normalized Loss = tensor(0.0176)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0022)
#
#  Iteration no: 103
# torch.Size([5000])
# Normalized Loss = tensor(0.0167)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0022)
#
#  Iteration no: 104
# torch.Size([5000])
# Normalized Loss = tensor(0.0188)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0022)
#
#  Iteration no: 105
# torch.Size([5000])
# Normalized Loss = tensor(0.0176)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0022)
#
#  Iteration no: 106
# torch.Size([5000])
# Normalized Loss = tensor(0.0193)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0023)
#
#  Iteration no: 107
# torch.Size([5000])
# Normalized Loss = tensor(0.0147)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0023)
#
#  Iteration no: 108
# torch.Size([5000])
# Normalized Loss = tensor(0.0191)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0023)
#
#  Iteration no: 109
# torch.Size([5000])
# Normalized Loss = tensor(0.0219)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0023)
#
#  Iteration no: 110
# torch.Size([5000])
# Normalized Loss = tensor(0.0150)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0023)
#
#  Iteration no: 111
# torch.Size([5000])
# Normalized Loss = tensor(0.0193)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0023)
#
#  Iteration no: 112
# torch.Size([5000])
# Normalized Loss = tensor(0.0197)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0024)
#
#  Iteration no: 113
# torch.Size([5000])
# Normalized Loss = tensor(0.0169)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0024)
#
#  Iteration no: 114
# torch.Size([5000])
# Normalized Loss = tensor(0.0219)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0024)
#
#  Iteration no: 115
# torch.Size([5000])
# Normalized Loss = tensor(0.0135)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0024)
#
#  Iteration no: 116
# torch.Size([5000])
# Normalized Loss = tensor(0.0151)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0024)
#
#  Iteration no: 117
# torch.Size([5000])
# Normalized Loss = tensor(0.0156)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0024)
#
#  Iteration no: 118
# torch.Size([5000])
# Normalized Loss = tensor(0.0193)
# Median Learning Rate: tensor(0.0005)
# Avg. Learning Rate: tensor(0.0025)
#
#  Iteration no: 119
# torch.Size([5000])
# Normalized Loss = tensor(0.0149)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0025)
#
#  Iteration no: 120
# torch.Size([5000])
# Normalized Loss = tensor(0.0151)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0025)
#
#  Iteration no: 121
# torch.Size([5000])
# Normalized Loss = tensor(0.0154)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0025)
#
#  Iteration no: 122
# torch.Size([5000])
# Normalized Loss = tensor(0.0128)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0026)
#
#  Iteration no: 123
# torch.Size([5000])
# Normalized Loss = tensor(0.0155)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0026)
#
#  Iteration no: 124
# torch.Size([5000])
# Normalized Loss = tensor(0.0120)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0026)
#
#  Iteration no: 125
# torch.Size([5000])
# Normalized Loss = tensor(0.0150)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0026)
#
#  Iteration no: 126
# torch.Size([5000])
# Normalized Loss = tensor(0.0154)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0026)
#
#  Iteration no: 127
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0027)
#
#  Iteration no: 128
# torch.Size([5000])
# Normalized Loss = tensor(0.0155)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0027)
#
#  Iteration no: 129
# torch.Size([5000])
# Normalized Loss = tensor(0.0144)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0027)
#
#  Iteration no: 130
# torch.Size([5000])
# Normalized Loss = tensor(0.0153)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0027)
#
#  Iteration no: 131
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0028)
#
#  Iteration no: 132
# torch.Size([5000])
# Normalized Loss = tensor(0.0128)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0028)
#
#  Iteration no: 133
# torch.Size([5000])
# Normalized Loss = tensor(0.0149)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0028)
#
#  Iteration no: 134
# torch.Size([5000])
# Normalized Loss = tensor(0.0155)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0028)
#
#  Iteration no: 135
# torch.Size([5000])
# Normalized Loss = tensor(0.0151)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0029)
#
#  Iteration no: 136
# torch.Size([5000])
# Normalized Loss = tensor(0.0155)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0029)
#
#  Iteration no: 137
# torch.Size([5000])
# Normalized Loss = tensor(0.0181)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0029)
#
#  Iteration no: 138
# torch.Size([5000])
# Normalized Loss = tensor(0.0153)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0029)
#
#  Iteration no: 139
# torch.Size([5000])
# Normalized Loss = tensor(0.0147)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0029)
#
#  Iteration no: 140
# torch.Size([5000])
# Normalized Loss = tensor(0.0154)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0030)
#
#  Iteration no: 141
# torch.Size([5000])
# Normalized Loss = tensor(0.0107)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0030)
#
#  Iteration no: 142
# torch.Size([5000])
# Normalized Loss = tensor(0.0152)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0030)
#
#  Iteration no: 143
# torch.Size([5000])
# Normalized Loss = tensor(0.0125)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0030)
#
#  Iteration no: 144
# torch.Size([5000])
# Normalized Loss = tensor(0.0177)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0030)
#
#  Iteration no: 145
# torch.Size([5000])
# Normalized Loss = tensor(0.0154)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0031)
#
#  Iteration no: 146
# torch.Size([5000])
# Normalized Loss = tensor(0.0127)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0031)
#
#  Iteration no: 147
# torch.Size([5000])
# Normalized Loss = tensor(0.0171)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0031)
#
#  Iteration no: 148
# torch.Size([5000])
# Normalized Loss = tensor(0.0153)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0032)
#
#  Iteration no: 149
# torch.Size([5000])
# Normalized Loss = tensor(0.0133)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0032)
#
#  Iteration no: 150
# torch.Size([5000])
# Normalized Loss = tensor(0.0148)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0032)
#
#  Iteration no: 151
# torch.Size([5000])
# Normalized Loss = tensor(0.0152)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0032)
#
#  Iteration no: 152
# torch.Size([5000])
# Normalized Loss = tensor(0.0153)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0033)
#
#  Iteration no: 153
# torch.Size([5000])
# Normalized Loss = tensor(0.0149)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0033)
#
#  Iteration no: 154
# torch.Size([5000])
# Normalized Loss = tensor(0.0152)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0033)
#
#  Iteration no: 155
# torch.Size([5000])
# Normalized Loss = tensor(0.0153)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0033)
#
#  Iteration no: 156
# torch.Size([5000])
# Normalized Loss = tensor(0.0150)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0034)
#
#  Iteration no: 157
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0034)
#
#  Iteration no: 158
# torch.Size([5000])
# Normalized Loss = tensor(0.0181)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0034)
#
#  Iteration no: 159
# torch.Size([5000])
# Normalized Loss = tensor(0.0145)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0034)
#
#  Iteration no: 160
# torch.Size([5000])
# Normalized Loss = tensor(0.0130)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0035)
#
#  Iteration no: 161
# torch.Size([5000])
# Normalized Loss = tensor(0.0153)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0035)
#
#  Iteration no: 162
# torch.Size([5000])
# Normalized Loss = tensor(0.0149)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0035)
#
#  Iteration no: 163
# torch.Size([5000])
# Normalized Loss = tensor(0.0152)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0036)
#
#  Iteration no: 164
# torch.Size([5000])
# Normalized Loss = tensor(0.0153)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0036)
#
#  Iteration no: 165
# torch.Size([5000])
# Normalized Loss = tensor(0.0148)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0036)
#
#  Iteration no: 166
# torch.Size([5000])
# Normalized Loss = tensor(0.0150)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0037)
#
#  Iteration no: 167
# torch.Size([5000])
# Normalized Loss = tensor(0.0152)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0037)
#
#  Iteration no: 168
# torch.Size([5000])
# Normalized Loss = tensor(0.0171)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0037)
#
#  Iteration no: 169
# torch.Size([5000])
# Normalized Loss = tensor(0.0152)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0038)
#
#  Iteration no: 170
# torch.Size([5000])
# Normalized Loss = tensor(0.0132)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0038)
#
#  Iteration no: 171
# torch.Size([5000])
# Normalized Loss = tensor(0.0172)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0038)
#
#  Iteration no: 172
# torch.Size([5000])
# Normalized Loss = tensor(0.0153)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0039)
#
#  Iteration no: 173
# torch.Size([5000])
# Normalized Loss = tensor(0.0177)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0039)
#
#  Iteration no: 174
# torch.Size([5000])
# Normalized Loss = tensor(0.0131)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0039)
#
#  Iteration no: 175
# torch.Size([5000])
# Normalized Loss = tensor(0.0152)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0040)
#
#  Iteration no: 176
# torch.Size([5000])
# Normalized Loss = tensor(0.0177)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0040)
#
#  Iteration no: 177
# torch.Size([5000])
# Normalized Loss = tensor(0.0155)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0040)
#
#  Iteration no: 178
# torch.Size([5000])
# Normalized Loss = tensor(0.0175)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0040)
#
#  Iteration no: 179
# torch.Size([5000])
# Normalized Loss = tensor(0.0152)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0040)
#
#  Iteration no: 180
# torch.Size([5000])
# Normalized Loss = tensor(0.0147)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0041)
#
#  Iteration no: 181
# torch.Size([5000])
# Normalized Loss = tensor(0.0119)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0041)
#
#  Iteration no: 182
# torch.Size([5000])
# Normalized Loss = tensor(0.0164)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0041)
#
#  Iteration no: 183
# torch.Size([5000])
# Normalized Loss = tensor(0.0161)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0042)
#
#  Iteration no: 184
# torch.Size([5000])
# Normalized Loss = tensor(0.0159)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0042)
#
#  Iteration no: 185
# torch.Size([5000])
# Normalized Loss = tensor(0.0159)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0043)
#
#  Iteration no: 186
# torch.Size([5000])
# Normalized Loss = tensor(0.0155)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0043)
#
#  Iteration no: 187
# torch.Size([5000])
# Normalized Loss = tensor(0.0149)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0043)
#
#  Iteration no: 188
# torch.Size([5000])
# Normalized Loss = tensor(0.0128)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0044)
#
#  Iteration no: 189
# torch.Size([5000])
# Normalized Loss = tensor(0.0144)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0044)
#
#  Iteration no: 190
# torch.Size([5000])
# Normalized Loss = tensor(0.0142)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0045)
#
#  Iteration no: 191
# torch.Size([5000])
# Normalized Loss = tensor(0.0138)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0045)
#
#  Iteration no: 192
# torch.Size([5000])
# Normalized Loss = tensor(0.0151)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0046)
#
#  Iteration no: 193
# torch.Size([5000])
# Normalized Loss = tensor(0.0141)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0046)
#
#  Iteration no: 194
# torch.Size([5000])
# Normalized Loss = tensor(0.0138)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0046)
#
#  Iteration no: 195
# torch.Size([5000])
# Normalized Loss = tensor(0.0151)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0047)
#
#  Iteration no: 196
# torch.Size([5000])
# Normalized Loss = tensor(0.0141)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0047)
#
#  Iteration no: 197
# torch.Size([5000])
# Normalized Loss = tensor(0.0120)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0048)
#
#  Iteration no: 198
# torch.Size([5000])
# Normalized Loss = tensor(0.0169)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0048)
#
#  Iteration no: 199
# torch.Size([5000])
# Normalized Loss = tensor(0.0144)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0048)
#
#  Iteration no: 200
# torch.Size([5000])
# Normalized Loss = tensor(0.0145)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0049)
#
#  Iteration no: 201
# torch.Size([5000])
# Normalized Loss = tensor(0.0137)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0049)
#
#  Iteration no: 202
# torch.Size([5000])
# Normalized Loss = tensor(0.0143)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0050)
#
#  Iteration no: 203
# torch.Size([5000])
# Normalized Loss = tensor(0.0144)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0050)
#
#  Iteration no: 204
# torch.Size([5000])
# Normalized Loss = tensor(0.0139)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0051)
#
#  Iteration no: 205
# torch.Size([5000])
# Normalized Loss = tensor(0.0141)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0051)
#
#  Iteration no: 206
# torch.Size([5000])
# Normalized Loss = tensor(0.0121)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0052)
#
#  Iteration no: 207
# torch.Size([5000])
# Normalized Loss = tensor(0.0144)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0052)
#
#  Iteration no: 208
# torch.Size([5000])
# Normalized Loss = tensor(0.0143)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0053)
#
#  Iteration no: 209
# torch.Size([5000])
# Normalized Loss = tensor(0.0141)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0053)
#
#  Iteration no: 210
# torch.Size([5000])
# Normalized Loss = tensor(0.0151)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0054)
#
#  Iteration no: 211
# torch.Size([5000])
# Normalized Loss = tensor(0.0143)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0054)
#
#  Iteration no: 212
# torch.Size([5000])
# Normalized Loss = tensor(0.0141)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0055)
#
#  Iteration no: 213
# torch.Size([5000])
# Normalized Loss = tensor(0.0172)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0055)
#
#  Iteration no: 214
# torch.Size([5000])
# Normalized Loss = tensor(0.0141)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0055)
#
#  Iteration no: 215
# torch.Size([5000])
# Normalized Loss = tensor(0.0117)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0056)
#
#  Iteration no: 216
# torch.Size([5000])
# Normalized Loss = tensor(0.0142)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0057)
#
#  Iteration no: 217
# torch.Size([5000])
# Normalized Loss = tensor(0.0141)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0057)
#
#  Iteration no: 218
# torch.Size([5000])
# Normalized Loss = tensor(0.0162)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0057)
#
#  Iteration no: 219
# torch.Size([5000])
# Normalized Loss = tensor(0.0147)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0058)
#
#  Iteration no: 220
# torch.Size([5000])
# Normalized Loss = tensor(0.0142)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0059)
#
#  Iteration no: 221
# torch.Size([5000])
# Normalized Loss = tensor(0.0139)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0059)
#
#  Iteration no: 222
# torch.Size([5000])
# Normalized Loss = tensor(0.0142)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0060)
#
#  Iteration no: 223
# torch.Size([5000])
# Normalized Loss = tensor(0.0138)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0060)
#
#  Iteration no: 224
# torch.Size([5000])
# Normalized Loss = tensor(0.0128)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0061)
#
#  Iteration no: 225
# torch.Size([5000])
# Normalized Loss = tensor(0.0136)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0061)
#
#  Iteration no: 226
# torch.Size([5000])
# Normalized Loss = tensor(0.0155)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0062)
#
#  Iteration no: 227
# torch.Size([5000])
# Normalized Loss = tensor(0.0102)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0062)
#
#  Iteration no: 228
# torch.Size([5000])
# Normalized Loss = tensor(0.0151)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0063)
#
#  Iteration no: 229
# torch.Size([5000])
# Normalized Loss = tensor(0.0123)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0064)
#
#  Iteration no: 230
# torch.Size([5000])
# Normalized Loss = tensor(0.0121)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0064)
#
#  Iteration no: 231
# torch.Size([5000])
# Normalized Loss = tensor(0.0132)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0065)
#
#  Iteration no: 232
# torch.Size([5000])
# Normalized Loss = tensor(0.0127)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0066)
#
#  Iteration no: 233
# torch.Size([5000])
# Normalized Loss = tensor(0.0124)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0066)
#
#  Iteration no: 234
# torch.Size([5000])
# Normalized Loss = tensor(0.0153)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0067)
#
#  Iteration no: 235
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0067)
#
#  Iteration no: 236
# torch.Size([5000])
# Normalized Loss = tensor(0.0149)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0068)
#
#  Iteration no: 237
# torch.Size([5000])
# Normalized Loss = tensor(0.0107)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0069)
#
#  Iteration no: 238
# torch.Size([5000])
# Normalized Loss = tensor(0.0125)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0069)
#
#  Iteration no: 239
# torch.Size([5000])
# Normalized Loss = tensor(0.0124)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0070)
#
#  Iteration no: 240
# torch.Size([5000])
# Normalized Loss = tensor(0.0146)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0071)
#
#  Iteration no: 241
# torch.Size([5000])
# Normalized Loss = tensor(0.0130)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0071)
#
#  Iteration no: 242
# torch.Size([5000])
# Normalized Loss = tensor(0.0123)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0072)
#
#  Iteration no: 243
# torch.Size([5000])
# Normalized Loss = tensor(0.0122)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0073)
#
#  Iteration no: 244
# torch.Size([5000])
# Normalized Loss = tensor(0.0129)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0073)
#
#  Iteration no: 245
# torch.Size([5000])
# Normalized Loss = tensor(0.0172)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0074)
#
#  Iteration no: 246
# torch.Size([5000])
# Normalized Loss = tensor(0.0108)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0075)
#
#  Iteration no: 247
# torch.Size([5000])
# Normalized Loss = tensor(0.0125)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0075)
#
#  Iteration no: 248
# torch.Size([5000])
# Normalized Loss = tensor(0.0123)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0076)
#
#  Iteration no: 249
# torch.Size([5000])
# Normalized Loss = tensor(0.0122)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0077)
#
#  Iteration no: 250
# torch.Size([5000])
# Normalized Loss = tensor(0.0122)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0078)
#
#  Iteration no: 251
# torch.Size([5000])
# Normalized Loss = tensor(0.0133)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0078)
#
#  Iteration no: 252
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0079)
#
#  Iteration no: 253
# torch.Size([5000])
# Normalized Loss = tensor(0.0125)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0080)
#
#  Iteration no: 254
# torch.Size([5000])
# Normalized Loss = tensor(0.0172)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0080)
#
#  Iteration no: 255
# torch.Size([5000])
# Normalized Loss = tensor(0.0131)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0081)
#
#  Iteration no: 256
# torch.Size([5000])
# Normalized Loss = tensor(0.0124)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0082)
#
#  Iteration no: 257
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0083)
#
#  Iteration no: 258
# torch.Size([5000])
# Normalized Loss = tensor(0.0124)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0084)
#
#  Iteration no: 259
# torch.Size([5000])
# Normalized Loss = tensor(0.0123)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0084)
#
#  Iteration no: 260
# torch.Size([5000])
# Normalized Loss = tensor(0.0146)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0085)
#
#  Iteration no: 261
# torch.Size([5000])
# Normalized Loss = tensor(0.0130)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0086)
#
#  Iteration no: 262
# torch.Size([5000])
# Normalized Loss = tensor(0.0121)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0087)
#
#  Iteration no: 263
# torch.Size([5000])
# Normalized Loss = tensor(0.0121)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0088)
#
#  Iteration no: 264
# torch.Size([5000])
# Normalized Loss = tensor(0.0132)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0088)
#
#  Iteration no: 265
# torch.Size([5000])
# Normalized Loss = tensor(0.0151)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0089)
#
#  Iteration no: 266
# torch.Size([5000])
# Normalized Loss = tensor(0.0117)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0090)
#
#  Iteration no: 267
# torch.Size([5000])
# Normalized Loss = tensor(0.0147)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0091)
#
#  Iteration no: 268
# torch.Size([5000])
# Normalized Loss = tensor(0.0123)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0092)
#
#  Iteration no: 269
# torch.Size([5000])
# Normalized Loss = tensor(0.0119)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0093)
#
#  Iteration no: 270
# torch.Size([5000])
# Normalized Loss = tensor(0.0130)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0094)
#
#  Iteration no: 271
# torch.Size([5000])
# Normalized Loss = tensor(0.0125)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0094)
#
#  Iteration no: 272
# torch.Size([5000])
# Normalized Loss = tensor(0.0123)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0095)
#
#  Iteration no: 273
# torch.Size([5000])
# Normalized Loss = tensor(0.0123)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0096)
#
#  Iteration no: 274
# torch.Size([5000])
# Normalized Loss = tensor(0.0145)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0097)
#
#  Iteration no: 275
# torch.Size([5000])
# Normalized Loss = tensor(0.0128)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0098)
#
#  Iteration no: 276
# torch.Size([5000])
# Normalized Loss = tensor(0.0148)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0099)
#
#  Iteration no: 277
# torch.Size([5000])
# Normalized Loss = tensor(0.0129)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0100)
#
#  Iteration no: 278
# torch.Size([5000])
# Normalized Loss = tensor(0.0121)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0101)
#
#  Iteration no: 279
# torch.Size([5000])
# Normalized Loss = tensor(0.0120)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0102)
#
#  Iteration no: 280
# torch.Size([5000])
# Normalized Loss = tensor(0.0120)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0103)
#
#  Iteration no: 281
# torch.Size([5000])
# Normalized Loss = tensor(0.0150)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0104)
#
#  Iteration no: 282
# torch.Size([5000])
# Normalized Loss = tensor(0.0121)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0105)
#
#  Iteration no: 283
# torch.Size([5000])
# Normalized Loss = tensor(0.0121)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0106)
#
#  Iteration no: 284
# torch.Size([5000])
# Normalized Loss = tensor(0.0121)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0107)
#
#  Iteration no: 285
# torch.Size([5000])
# Normalized Loss = tensor(0.0132)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0108)
#
#  Iteration no: 286
# torch.Size([5000])
# Normalized Loss = tensor(0.0150)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0109)
#
#  Iteration no: 287
# torch.Size([5000])
# Normalized Loss = tensor(0.0123)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0110)
#
#  Iteration no: 288
# torch.Size([5000])
# Normalized Loss = tensor(0.0144)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0111)
#
#  Iteration no: 289
# torch.Size([5000])
# Normalized Loss = tensor(0.0123)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0112)
#
#  Iteration no: 290
# torch.Size([5000])
# Normalized Loss = tensor(0.0118)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0113)
#
#  Iteration no: 291
# torch.Size([5000])
# Normalized Loss = tensor(0.0125)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0114)
#
#  Iteration no: 292
# torch.Size([5000])
# Normalized Loss = tensor(0.0122)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0115)
#
#  Iteration no: 293
# torch.Size([5000])
# Normalized Loss = tensor(0.0144)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0116)
#
#  Iteration no: 294
# torch.Size([5000])
# Normalized Loss = tensor(0.0120)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0118)
#
#  Iteration no: 295
# torch.Size([5000])
# Normalized Loss = tensor(0.0130)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0119)
#
#  Iteration no: 296
# torch.Size([5000])
# Normalized Loss = tensor(0.0150)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0120)
#
#  Iteration no: 297
# torch.Size([5000])
# Normalized Loss = tensor(0.0115)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0121)
#
#  Iteration no: 298
# torch.Size([5000])
# Normalized Loss = tensor(0.0124)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0122)
#
#  Iteration no: 299
# torch.Size([5000])
# Normalized Loss = tensor(0.0143)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0123)
#
#  Iteration no: 300
# torch.Size([5000])
# Normalized Loss = tensor(0.0121)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0124)
#
#  Iteration no: 301
# torch.Size([5000])
# Normalized Loss = tensor(0.0118)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0126)
#
#  Iteration no: 302
# torch.Size([5000])
# Normalized Loss = tensor(0.0130)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0127)
#
#  Iteration no: 303
# torch.Size([5000])
# Normalized Loss = tensor(0.0124)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0128)
#
#  Iteration no: 304
# torch.Size([5000])
# Normalized Loss = tensor(0.0149)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0129)
#
#  Iteration no: 305
# torch.Size([5000])
# Normalized Loss = tensor(0.0144)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0130)
#
#  Iteration no: 306
# torch.Size([5000])
# Normalized Loss = tensor(0.0122)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0131)
#
#  Iteration no: 307
# torch.Size([5000])
# Normalized Loss = tensor(0.0117)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0133)
#
#  Iteration no: 308
# torch.Size([5000])
# Normalized Loss = tensor(0.0117)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0134)
#
#  Iteration no: 309
# torch.Size([5000])
# Normalized Loss = tensor(0.0124)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0135)
#
#  Iteration no: 310
# torch.Size([5000])
# Normalized Loss = tensor(0.0144)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0136)
#
#  Iteration no: 311
# torch.Size([5000])
# Normalized Loss = tensor(0.0120)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0138)
#
#  Iteration no: 312
# torch.Size([5000])
# Normalized Loss = tensor(0.0121)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0139)
#
#  Iteration no: 313
# torch.Size([5000])
# Normalized Loss = tensor(0.0128)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0140)
#
#  Iteration no: 314
# torch.Size([5000])
# Normalized Loss = tensor(0.0149)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0141)
#
#  Iteration no: 315
# torch.Size([5000])
# Normalized Loss = tensor(0.0115)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0143)
#
#  Iteration no: 316
# torch.Size([5000])
# Normalized Loss = tensor(0.0123)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0144)
#
#  Iteration no: 317
# torch.Size([5000])
# Normalized Loss = tensor(0.0143)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0146)
#
#  Iteration no: 318
# torch.Size([5000])
# Normalized Loss = tensor(0.0120)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0147)
#
#  Iteration no: 319
# torch.Size([5000])
# Normalized Loss = tensor(0.0118)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0149)
#
#  Iteration no: 320
# torch.Size([5000])
# Normalized Loss = tensor(0.0125)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0150)
#
#  Iteration no: 321
# torch.Size([5000])
# Normalized Loss = tensor(0.0145)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0151)
#
#  Iteration no: 322
# torch.Size([5000])
# Normalized Loss = tensor(0.0121)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0153)
#
#  Iteration no: 323
# torch.Size([5000])
# Normalized Loss = tensor(0.0119)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0154)
#
#  Iteration no: 324
# torch.Size([5000])
# Normalized Loss = tensor(0.0119)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0156)
#
#  Iteration no: 325
# torch.Size([5000])
# Normalized Loss = tensor(0.0173)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0157)
#
#  Iteration no: 326
# torch.Size([5000])
# Normalized Loss = tensor(0.0122)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0158)
#
#  Iteration no: 327
# torch.Size([5000])
# Normalized Loss = tensor(0.0120)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0160)
#
#  Iteration no: 328
# torch.Size([5000])
# Normalized Loss = tensor(0.0117)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0161)
#
#  Iteration no: 329
# torch.Size([5000])
# Normalized Loss = tensor(0.0124)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0163)
#
#  Iteration no: 330
# torch.Size([5000])
# Normalized Loss = tensor(0.0122)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0164)
#
#  Iteration no: 331
# torch.Size([5000])
# Normalized Loss = tensor(0.0120)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0166)
#
#  Iteration no: 332
# torch.Size([5000])
# Normalized Loss = tensor(0.0167)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0167)
#
#  Iteration no: 333
# torch.Size([5000])
# Normalized Loss = tensor(0.0128)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0169)
#
#  Iteration no: 334
# torch.Size([5000])
# Normalized Loss = tensor(0.0143)
# ...
#
#  Iteration no: 390
# torch.Size([5000])
# Normalized Loss = tensor(0.0073)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0283)
#
#  Iteration no: 391
# torch.Size([5000])
# Normalized Loss = tensor(0.0114)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0286)
#
#  Iteration no: 392
# torch.Size([5000])
# Normalized Loss = tensor(0.0071)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0289)
#
#  Iteration no: 393
# torch.Size([5000])
# Normalized Loss = tensor(0.0099)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0292)
#
#  Iteration no: 394
# torch.Size([5000])
# Normalized Loss = tensor(0.0092)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0294)
#
#  Iteration no: 395
# torch.Size([5000])
# Normalized Loss = tensor(0.0105)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0293)
#
#  Iteration no: 396
# torch.Size([5000])
# Normalized Loss = tensor(0.0075)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0296)
#
#  Iteration no: 397
# torch.Size([5000])
# Normalized Loss = tensor(0.0076)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0299)
#
#  Iteration no: 398
# torch.Size([5000])
# Normalized Loss = tensor(0.0076)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0302)
#
#  Iteration no: 399
# torch.Size([5000])
# Normalized Loss = tensor(0.0076)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0305)
#
#  Iteration no: 400
# torch.Size([5000])
# Normalized Loss = tensor(0.0099)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0307)
#
#  Iteration no: 401
# torch.Size([5000])
# Normalized Loss = tensor(0.0075)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0310)
#
#  Iteration no: 402
# torch.Size([5000])
# Normalized Loss = tensor(0.0115)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0313)
#
#  Iteration no: 403
# torch.Size([5000])
# Normalized Loss = tensor(0.0104)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0316)
#
#  Iteration no: 404
# torch.Size([5000])
# Normalized Loss = tensor(0.0071)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0319)
#
#  Iteration no: 405
# torch.Size([5000])
# Normalized Loss = tensor(0.0069)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0322)
#
#  Iteration no: 406
# torch.Size([5000])
# Normalized Loss = tensor(0.0069)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0325)
#
#  Iteration no: 407
# torch.Size([5000])
# Normalized Loss = tensor(0.0091)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0327)
#
#  Iteration no: 408
# torch.Size([5000])
# Normalized Loss = tensor(0.0079)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0330)
#
#  Iteration no: 409
# torch.Size([5000])
# Normalized Loss = tensor(0.0074)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0333)
#
#  Iteration no: 410
# torch.Size([5000])
# Normalized Loss = tensor(0.0073)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0337)
#
#  Iteration no: 411
# torch.Size([5000])
# Normalized Loss = tensor(0.0074)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0340)
#
#  Iteration no: 412
# torch.Size([5000])
# Normalized Loss = tensor(0.0073)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0343)
#
#  Iteration no: 413
# torch.Size([5000])
# Normalized Loss = tensor(0.0074)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0347)
#
#  Iteration no: 414
# torch.Size([5000])
# Normalized Loss = tensor(0.0080)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0350)
#
#  Iteration no: 415
# torch.Size([5000])
# Normalized Loss = tensor(0.0104)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0353)
#
#  Iteration no: 416
# torch.Size([5000])
# Normalized Loss = tensor(0.0093)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0355)
#
#  Iteration no: 417
# torch.Size([5000])
# Normalized Loss = tensor(0.0078)
# Median Learning Rate: tensor(0.0006)
# Avg. Learning Rate: tensor(0.0358)
#
#  Iteration no: 418
# torch.Size([5000])
# Normalized Loss = tensor(0.0077)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0362)
#
#  Iteration no: 419
# torch.Size([5000])
# Normalized Loss = tensor(0.0072)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0366)
#
#  Iteration no: 420
# torch.Size([5000])
# Normalized Loss = tensor(0.0073)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0369)
#
#  Iteration no: 421
# torch.Size([5000])
# Normalized Loss = tensor(0.0073)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0373)
#
#  Iteration no: 422
# torch.Size([5000])
# Normalized Loss = tensor(0.0073)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0377)
#
#  Iteration no: 423
# torch.Size([5000])
# Normalized Loss = tensor(0.0096)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0379)
#
#  Iteration no: 424
# torch.Size([5000])
# Normalized Loss = tensor(0.0077)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0383)
#
#  Iteration no: 425
# torch.Size([5000])
# Normalized Loss = tensor(0.0077)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0386)
#
#  Iteration no: 426
# torch.Size([5000])
# Normalized Loss = tensor(0.0102)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0390)
#
#  Iteration no: 427
# torch.Size([5000])
# Normalized Loss = tensor(0.0070)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0394)
#
#  Iteration no: 428
# torch.Size([5000])
# Normalized Loss = tensor(0.0076)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0398)
#
#  Iteration no: 429
# torch.Size([5000])
# Normalized Loss = tensor(0.0074)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0402)
#
#  Iteration no: 430
# torch.Size([5000])
# Normalized Loss = tensor(0.0073)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0406)
#
#  Iteration no: 431
# torch.Size([5000])
# Normalized Loss = tensor(0.0073)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0410)
#
#  Iteration no: 432
# torch.Size([5000])
# Normalized Loss = tensor(0.0073)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0414)
#
#  Iteration no: 433
# torch.Size([5000])
# Normalized Loss = tensor(0.0096)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0417)
#
#  Iteration no: 434
# torch.Size([5000])
# Normalized Loss = tensor(0.0078)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0421)
#
#  Iteration no: 435
# torch.Size([5000])
# Normalized Loss = tensor(0.0071)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0425)
#
#  Iteration no: 436
# torch.Size([5000])
# Normalized Loss = tensor(0.0070)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0430)
#
#  Iteration no: 437
# torch.Size([5000])
# Normalized Loss = tensor(0.0077)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0434)
#
#  Iteration no: 438
# torch.Size([5000])
# Normalized Loss = tensor(0.0077)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0438)
#
#  Iteration no: 439
# torch.Size([5000])
# Normalized Loss = tensor(0.0102)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0442)
#
#  Iteration no: 440
# torch.Size([5000])
# Normalized Loss = tensor(0.0093)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0445)
#
#  Iteration no: 441
# torch.Size([5000])
# Normalized Loss = tensor(0.0078)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0448)
#
#  Iteration no: 442
# torch.Size([5000])
# Normalized Loss = tensor(0.0077)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0453)
#
#  Iteration no: 443
# torch.Size([5000])
# Normalized Loss = tensor(0.0071)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0457)
#
#  Iteration no: 444
# torch.Size([5000])
# Normalized Loss = tensor(0.0071)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0462)
#
#  Iteration no: 445
# torch.Size([5000])
# Normalized Loss = tensor(0.0071)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0466)
#
#  Iteration no: 446
# torch.Size([5000])
# Normalized Loss = tensor(0.0070)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0471)
#
#  Iteration no: 447
# torch.Size([5000])
# Normalized Loss = tensor(0.0077)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0476)
#
#  Iteration no: 448
# torch.Size([5000])
# Normalized Loss = tensor(0.0077)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0481)
#
#  Iteration no: 449
# torch.Size([5000])
# Normalized Loss = tensor(0.0099)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0484)
#
#  Iteration no: 450
# torch.Size([5000])
# Normalized Loss = tensor(0.0077)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0489)
#
#  Iteration no: 451
# torch.Size([5000])
# Normalized Loss = tensor(0.0074)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0493)
#
#  Iteration no: 452
# torch.Size([5000])
# Normalized Loss = tensor(0.0099)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0498)
#
#  Iteration no: 453
# torch.Size([5000])
# Normalized Loss = tensor(0.0078)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0503)
#
#  Iteration no: 454
# torch.Size([5000])
# Normalized Loss = tensor(0.0071)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0508)
#
#  Iteration no: 455
# torch.Size([5000])
# Normalized Loss = tensor(0.0070)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0513)
#
#  Iteration no: 456
# torch.Size([5000])
# Normalized Loss = tensor(0.0094)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0517)
#
#  Iteration no: 457
# torch.Size([5000])
# Normalized Loss = tensor(0.0078)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0522)
#
#  Iteration no: 458
# torch.Size([5000])
# Normalized Loss = tensor(0.0069)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0527)
#
#  Iteration no: 459
# torch.Size([5000])
# Normalized Loss = tensor(0.0076)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0532)
#
#  Iteration no: 460
# torch.Size([5000])
# Normalized Loss = tensor(0.0075)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0538)
#
#  Iteration no: 461
# torch.Size([5000])
# Normalized Loss = tensor(0.0075)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0543)
#
#  Iteration no: 462
# torch.Size([5000])
# Normalized Loss = tensor(0.0074)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0549)
#
#  Iteration no: 463
# torch.Size([5000])
# Normalized Loss = tensor(0.0097)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0553)
#
#  Iteration no: 464
# torch.Size([5000])
# Normalized Loss = tensor(0.0078)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0558)
#
#  Iteration no: 465
# torch.Size([5000])
# Normalized Loss = tensor(0.0078)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0564)
#
#  Iteration no: 466
# torch.Size([5000])
# Normalized Loss = tensor(0.0102)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0569)
#
#  Iteration no: 467
# torch.Size([5000])
# Normalized Loss = tensor(0.0071)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0575)
#
#  Iteration no: 468
# torch.Size([5000])
# Normalized Loss = tensor(0.0071)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0581)
#
#  Iteration no: 469
# torch.Size([5000])
# Normalized Loss = tensor(0.0069)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0586)
#
#  Iteration no: 470
# torch.Size([5000])
# Normalized Loss = tensor(0.0076)
# Median Learning Rate: tensor(0.0009)
# Avg. Learning Rate: tensor(0.0592)
#
#  Iteration no: 471
# torch.Size([5000])
# Normalized Loss = tensor(0.0097)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0595)
#
#  Iteration no: 472
# torch.Size([5000])
# Normalized Loss = tensor(0.0077)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0601)
#
#  Iteration no: 473
# torch.Size([5000])
# Normalized Loss = tensor(0.0070)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0607)
#
#  Iteration no: 474
# torch.Size([5000])
# Normalized Loss = tensor(0.0070)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0613)
#
#  Iteration no: 475
# torch.Size([5000])
# Normalized Loss = tensor(0.0070)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0619)
#
#  Iteration no: 476
# torch.Size([5000])
# Normalized Loss = tensor(0.0077)
# Median Learning Rate: tensor(0.0007)
# Avg. Learning Rate: tensor(0.0625)
#
#  Iteration no: 477
# torch.Size([5000])
# Normalized Loss = tensor(0.0077)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0631)
#
#  Iteration no: 478
# torch.Size([5000])
# Normalized Loss = tensor(0.0101)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0637)
#
#  Iteration no: 479
# torch.Size([5000])
# Normalized Loss = tensor(0.0069)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0643)
#
#  Iteration no: 480
# torch.Size([5000])
# Normalized Loss = tensor(0.0070)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0650)
#
#  Iteration no: 481
# torch.Size([5000])
# Normalized Loss = tensor(0.0077)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0656)
#
#  Iteration no: 482
# torch.Size([5000])
# Normalized Loss = tensor(0.0095)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0662)
#
#  Iteration no: 483
# torch.Size([5000])
# Normalized Loss = tensor(0.0076)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0669)
#
#  Iteration no: 484
# torch.Size([5000])
# Normalized Loss = tensor(0.0070)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0676)
#
#  Iteration no: 485
# torch.Size([5000])
# Normalized Loss = tensor(0.0069)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0682)
#
#  Iteration no: 486
# torch.Size([5000])
# Normalized Loss = tensor(0.0077)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0689)
#
#  Iteration no: 487
# torch.Size([5000])
# Normalized Loss = tensor(0.0099)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0693)
#
#  Iteration no: 488
# torch.Size([5000])
# Normalized Loss = tensor(0.0076)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0700)
#
#  Iteration no: 489
# torch.Size([5000])
# Normalized Loss = tensor(0.0072)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0707)
#
#  Iteration no: 490
# torch.Size([5000])
# Normalized Loss = tensor(0.0072)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0714)
#
#  Iteration no: 491
# torch.Size([5000])
# Normalized Loss = tensor(0.0096)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0721)
#
#  Iteration no: 492
# torch.Size([5000])
# Normalized Loss = tensor(0.0076)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0728)
#
#  Iteration no: 493
# torch.Size([5000])
# Normalized Loss = tensor(0.0069)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0735)
#
#  Iteration no: 494
# torch.Size([5000])
# Normalized Loss = tensor(0.0068)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0743)
#
#  Iteration no: 495
# torch.Size([5000])
# Normalized Loss = tensor(0.0067)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0750)
#
#  Iteration no: 496
# torch.Size([5000])
# Normalized Loss = tensor(0.0074)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0757)
#
#  Iteration no: 497
# torch.Size([5000])
# Normalized Loss = tensor(0.0096)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0764)
#
#  Iteration no: 498
# torch.Size([5000])
# Normalized Loss = tensor(0.0075)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0771)
#
#  Iteration no: 499
# torch.Size([5000])
# Normalized Loss = tensor(0.0071)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0779)
#
#  Iteration no: 500
# torch.Size([5000])
# Normalized Loss = tensor(0.0071)
# Median Learning Rate: tensor(0.0008)
# Avg. Learning Rate: tensor(0.0787)

# %%
plot_neuron_dynamics(mem_rec, spk_rec, error_rec, target)
plt.savefig(f"{images_dir}/after 100 epochs.png")

# %%
counter = 100
for i in range(100):
  counter += 1
  print("Iteration:", counter)
  mem_rec, spk_rec, error_rec, eligibility_rec, pre_trace_rec = run_single_neuron(input_trains, weights,
                                                                                  target, args)
 # loss = van_rossum_loss(spk_rec, target, args)
 # print("Loss = ", loss)
  norm_loss = van_rossum_loss2(spk_rec, target, args)
  print("Normalized Loss =", norm_loss)
  loss_rec.append(norm_loss)
  # normalizing the eligibility trace:
 # print("Eligibilty shape:", eligibility_rec.shape)
  norm_factor, _ = torch.max(torch.abs(eligibility_rec), dim=2) # take max along time dimension for each i-jth synapse
 # print("Eligibility Norm_factor shape:", norm_factor.shape)
  norm_factor = torch.unsqueeze(norm_factor, 2)
 # print("Normalization Factor for Eligibility:",norm_factor)
 # print("Eligibility Norm_factor shape after unsequeeze:", norm_factor.shape)
  eligibility_rec = eligibility_rec / norm_factor
 # print("Normalized Eligibility rec:", eligibility_rec)
  eligibility_rec[eligibility_rec != eligibility_rec] = 0
 # print(torch.max(eligibility_rec))
 # print("eligibility_rec shape:", eligibility_rec.shape)

  # normalizing the error signal:
  norm_factor = torch.max(torch.abs(error_rec))
  error_rec = error_rec / norm_factor
#  print("max error value:", torch.max(error_rec))
#  print("Post normalization Error rec:", error_rec)
 # print("Error Signal shape:", error_rec.shape)
  # Weight update
  weight_updates = torch.sum(error_rec * eligibility_rec, dim=2)
  #print(weight_updates.shape)
#  print("Weight Updates:", weight_updates.T)

  # per-parameter learning rate
  gamma = float(np.exp(-dt/args['tau_rms']))
 # print("Gamma =", gamma)
  g_ij2 = (error_rec * eligibility_rec)[:, :, -1]**2
#  print("g_ij2 =", g_ij2)
  v_ij = torch.max(gamma*v_ij, g_ij2)

  r_ij = r_0 / torch.sqrt(v_ij)
#  print("Per-parameter learning rates:", r_ij.T)
#  print("change in weights =", (r_ij*weight_updates).T)
  weights += r_ij * weight_updates
# Out:
# Iteration: 101
# torch.Size([5000])
# Normalized Loss = tensor(0.0080)
# Iteration: 102
# torch.Size([5000])
# Normalized Loss = tensor(0.0125)
# Iteration: 103
# torch.Size([5000])
# Normalized Loss = tensor(0.0111)
# Iteration: 104
# torch.Size([5000])
# Normalized Loss = tensor(0.0113)
# Iteration: 105
# torch.Size([5000])
# Normalized Loss = tensor(0.0120)
# Iteration: 106
# torch.Size([5000])
# Normalized Loss = tensor(0.0115)
# Iteration: 107
# torch.Size([5000])
# Normalized Loss = tensor(0.0123)
# Iteration: 108
# torch.Size([5000])
# Normalized Loss = tensor(0.0122)
# Iteration: 109
# torch.Size([5000])
# Normalized Loss = tensor(0.0087)
# Iteration: 110
# torch.Size([5000])
# Normalized Loss = tensor(0.0103)
# Iteration: 111
# torch.Size([5000])
# Normalized Loss = tensor(0.0066)
# Iteration: 112
# torch.Size([5000])
# Normalized Loss = tensor(0.0143)
# Iteration: 113
# torch.Size([5000])
# Normalized Loss = tensor(0.0114)
# Iteration: 114
# torch.Size([5000])
# Normalized Loss = tensor(0.0301)
# Iteration: 115
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Iteration: 116
# torch.Size([5000])
# Normalized Loss = tensor(0.0208)
# Iteration: 117
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Iteration: 118
# torch.Size([5000])
# Normalized Loss = tensor(0.0284)
# Iteration: 119
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Iteration: 120
# torch.Size([5000])
# Normalized Loss = tensor(0.0321)
# Iteration: 121
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Iteration: 122
# torch.Size([5000])
# Normalized Loss = tensor(0.0224)
# Iteration: 123
# torch.Size([5000])
# Normalized Loss = tensor(0.0099)
# Iteration: 124
# torch.Size([5000])
# Normalized Loss = tensor(0.0160)
# Iteration: 125
# torch.Size([5000])
# Normalized Loss = tensor(0.0101)
# Iteration: 126
# torch.Size([5000])
# Normalized Loss = tensor(0.0197)
# Iteration: 127
# torch.Size([5000])
# Normalized Loss = tensor(0.0113)
# Iteration: 128
# torch.Size([5000])
# Normalized Loss = tensor(0.0239)
# Iteration: 129
# torch.Size([5000])
# Normalized Loss = tensor(0.0117)
# Iteration: 130
# torch.Size([5000])
# Normalized Loss = tensor(0.0273)
# Iteration: 131
# torch.Size([5000])
# Normalized Loss = tensor(0.0107)
# Iteration: 132
# torch.Size([5000])
# Normalized Loss = tensor(0.0176)
# Iteration: 133
# torch.Size([5000])
# Normalized Loss = tensor(0.0128)
# Iteration: 134
# torch.Size([5000])
# Normalized Loss = tensor(0.0161)
# Iteration: 135
# torch.Size([5000])
# Normalized Loss = tensor(0.0130)
# Iteration: 136
# torch.Size([5000])
# Normalized Loss = tensor(0.0180)
# Iteration: 137
# torch.Size([5000])
# Normalized Loss = tensor(0.0113)
# Iteration: 138
# torch.Size([5000])
# Normalized Loss = tensor(0.0247)
# Iteration: 139
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Iteration: 140
# torch.Size([5000])
# Normalized Loss = tensor(0.0339)
# Iteration: 141
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Iteration: 142
# torch.Size([5000])
# Normalized Loss = tensor(0.0159)
# Iteration: 143
# torch.Size([5000])
# Normalized Loss = tensor(0.0136)
# Iteration: 144
# torch.Size([5000])
# Normalized Loss = tensor(0.0196)
# Iteration: 145
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Iteration: 146
# torch.Size([5000])
# Normalized Loss = tensor(0.0280)
# Iteration: 147
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Iteration: 148
# torch.Size([5000])
# Normalized Loss = tensor(0.0322)
# Iteration: 149
# torch.Size([5000])
# Normalized Loss = tensor(0.0111)
# Iteration: 150
# torch.Size([5000])
# Normalized Loss = tensor(0.0208)
# Iteration: 151
# torch.Size([5000])
# Normalized Loss = tensor(0.0117)
# Iteration: 152
# torch.Size([5000])
# Normalized Loss = tensor(0.0237)
# Iteration: 153
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Iteration: 154
# torch.Size([5000])
# Normalized Loss = tensor(0.0291)
# Iteration: 155
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Iteration: 156
# torch.Size([5000])
# Normalized Loss = tensor(0.0289)
# Iteration: 157
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Iteration: 158
# torch.Size([5000])
# Normalized Loss = tensor(0.0308)
# Iteration: 159
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Iteration: 160
# torch.Size([5000])
# Normalized Loss = tensor(0.0253)
# Iteration: 161
# torch.Size([5000])
# Normalized Loss = tensor(0.0122)
# Iteration: 162
# torch.Size([5000])
# Normalized Loss = tensor(0.0257)
# Iteration: 163
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Iteration: 164
# torch.Size([5000])
# Normalized Loss = tensor(0.0226)
# Iteration: 165
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Iteration: 166
# torch.Size([5000])
# Normalized Loss = tensor(0.0254)
# Iteration: 167
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Iteration: 168
# torch.Size([5000])
# Normalized Loss = tensor(0.0220)
# Iteration: 169
# torch.Size([5000])
# Normalized Loss = tensor(0.0098)
# Iteration: 170
# torch.Size([5000])
# Normalized Loss = tensor(0.0101)
# Iteration: 171
# torch.Size([5000])
# Normalized Loss = tensor(0.0120)
# Iteration: 172
# torch.Size([5000])
# Normalized Loss = tensor(0.0105)
# Iteration: 173
# torch.Size([5000])
# Normalized Loss = tensor(0.0123)
# Iteration: 174
# torch.Size([5000])
# Normalized Loss = tensor(0.0108)
# Iteration: 175
# torch.Size([5000])
# Normalized Loss = tensor(0.0125)
# Iteration: 176
# torch.Size([5000])
# Normalized Loss = tensor(0.0128)
# Iteration: 177
# torch.Size([5000])
# Normalized Loss = tensor(0.0151)
# Iteration: 178
# torch.Size([5000])
# Normalized Loss = tensor(0.0129)
# Iteration: 179
# torch.Size([5000])
# Normalized Loss = tensor(0.0201)
# Iteration: 180
# torch.Size([5000])
# Normalized Loss = tensor(0.0147)
# Iteration: 181
# torch.Size([5000])
# Normalized Loss = tensor(0.0216)
# Iteration: 182
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Iteration: 183
# torch.Size([5000])
# Normalized Loss = tensor(0.0396)
# Iteration: 184
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Iteration: 185
# torch.Size([5000])
# Normalized Loss = tensor(0.0223)
# Iteration: 186
# torch.Size([5000])
# Normalized Loss = tensor(0.0113)
# Iteration: 187
# torch.Size([5000])
# Normalized Loss = tensor(0.0177)
# Iteration: 188
# torch.Size([5000])
# Normalized Loss = tensor(0.0120)
# Iteration: 189
# torch.Size([5000])
# Normalized Loss = tensor(0.0269)
# Iteration: 190
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Iteration: 191
# torch.Size([5000])
# Normalized Loss = tensor(0.0341)
# Iteration: 192
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Iteration: 193
# torch.Size([5000])
# Normalized Loss = tensor(0.0181)
# Iteration: 194
# torch.Size([5000])
# Normalized Loss = tensor(0.0147)
# Iteration: 195
# torch.Size([5000])
# Normalized Loss = tensor(0.0182)
# Iteration: 196
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Iteration: 197
# torch.Size([5000])
# Normalized Loss = tensor(0.0299)
# Iteration: 198
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)
# Iteration: 199
# torch.Size([5000])
# Normalized Loss = tensor(0.0309)
# Iteration: 200
# torch.Size([5000])
# Normalized Loss = tensor(0.0126)

# %%
weights[weights != weights] = 0
plot_weight_distribution(weights)
#print(weights)
#plot_neuron_dynamics(mem_rec, spk_rec, error_rec, target)

# %%
plt.figure(dpi=100)
plt.plot(loss_rec)
plt.title("Loss over epochs")
plt.savefig(f'{images_dir}\loss over 200 epochs.png')
